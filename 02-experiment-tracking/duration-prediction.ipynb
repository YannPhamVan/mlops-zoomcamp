# %%
# !python -V
# Out:
# Python 3.9.21

# %%
import pandas as pd

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import root_mean_squared_error

# %%
import mlflow


mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='/workspaces/mlops-zoomcamp/02-experiment-tracking/mlruns/1', creation_time=1747667844436, experiment_id='1', last_update_time=1747667844436, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

root_mean_squared_error(y_val, y_pred)
# Out:
# 7.758715208009878

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "cristian")

    mlflow.log_param("train-data-path", "https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-01.parquet")
    mlflow.log_param("valid-data-path", "https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-02.parquet")

    alpha = 0.01
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = root_mean_squared_error(y_val, y_pred)
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = root_mean_squared_error(y_val, y_pred)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [17:15:45] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:7.11014
# [1]	validation-rmse:6.69737
# [2]	validation-rmse:6.63209
# [3]	validation-rmse:6.61275
# [4]	validation-rmse:6.59520
# [5]	validation-rmse:6.58708
# [6]	validation-rmse:6.58107
# [7]	validation-rmse:6.57883
# [8]	validation-rmse:6.57498
# [9]	validation-rmse:6.57087
# [10]	validation-rmse:6.56498
# [11]	validation-rmse:6.56963
# [12]	validation-rmse:6.56414
# [13]	validation-rmse:6.55937
# [14]	validation-rmse:6.55618
# [15]	validation-rmse:6.55015
# [16]	validation-rmse:6.54883
# [17]	validation-rmse:6.54529
# [18]	validation-rmse:6.54460
# [19]	validation-rmse:6.54200
# [20]	validation-rmse:6.53786
# [21]	validation-rmse:6.54024
# [22]	validation-rmse:6.53662
# [23]	validation-rmse:6.53113
# [24]	validation-rmse:6.52919
# [25]	validation-rmse:6.52639
# [26]	validation-rmse:6.52443
# [27]	validation-rmse:6.51995
# [28]	validation-rmse:6.51971
# [29]	validation-rmse:6.51654
# [30]	validation-rmse:6.51638
# [31]	validation-rmse:6.51540
# [32]	validation-rmse:6.51440
# [33]	validation-rmse:6.51422
# [34]	validation-rmse:6.51298
# [35]	validation-rmse:6.51171
# [36]	validation-rmse:6.51122
# [37]	validation-rmse:6.50763
# [38]	validation-rmse:6.50945
# [39]	validation-rmse:6.50617
# [40]	validation-rmse:6.49935
# [41]	validation-rmse:6.49581
# [42]	validation-rmse:6.49493
# [43]	validation-rmse:6.49885
# [44]	validation-rmse:6.49670
# [45]	validation-rmse:6.49508
# [46]	validation-rmse:6.49439
# [47]	validation-rmse:6.49471
# [48]	validation-rmse:6.49464
# [49]	validation-rmse:6.49560
# [50]	validation-rmse:6.49271
# [51]	validation-rmse:6.49113
# [52]	validation-rmse:6.48977
# [53]	validation-rmse:6.48744
# [54]	validation-rmse:6.47961
# [55]	validation-rmse:6.47901
# [56]	validation-rmse:6.48090
# [57]	validation-rmse:6.47993
# [58]	validation-rmse:6.47898
# [59]	validation-rmse:6.47833
# [60]	validation-rmse:6.47811
# [61]	validation-rmse:6.47816
# [62]	validation-rmse:6.47921
# [63]	validation-rmse:6.47859
# [64]	validation-rmse:6.47776
# [65]	validation-rmse:6.47643
# [66]	validation-rmse:6.47838
# [67]	validation-rmse:6.47770
# [68]	validation-rmse:6.47766
# [69]	validation-rmse:6.47878
# [70]	validation-rmse:6.47843
# [71]	validation-rmse:6.47853
# [72]	validation-rmse:6.47853
# [73]	validation-rmse:6.47654
# [74]	validation-rmse:6.47749
# [75]	validation-rmse:6.47657
# [76]	validation-rmse:6.47588
# [77]	validation-rmse:6.47667
# [78]	validation-rmse:6.47555
# [79]	validation-rmse:6.47596
# [80]	validation-rmse:6.47599
# [81]	validation-rmse:6.47473
# [82]	validation-rmse:6.47760
# [83]	validation-rmse:6.47923
# [84]	validation-rmse:6.47878
# [85]	validation-rmse:6.47959
# [86]	validation-rmse:6.47984
# [87]	validation-rmse:6.47983
# [88]	validation-rmse:6.47968
# [89]	validation-rmse:6.48112
# [90]	validation-rmse:6.48541
# [91]	validation-rmse:6.48666
# [92]	validation-rmse:6.48703
# [93]	validation-rmse:6.48860
# [94]	validation-rmse:6.48941
# [95]	validation-rmse:6.48957
# [96]	validation-rmse:6.49031
# [97]	validation-rmse:6.49034
# [98]	validation-rmse:6.49278
# [99]	validation-rmse:6.49643
# [100]	validation-rmse:6.49692
# [101]	validation-rmse:6.49721
# [102]	validation-rmse:6.49921
# [103]	validation-rmse:6.50071
# [104]	validation-rmse:6.50012
# [105]	validation-rmse:6.50051
# [106]	validation-rmse:6.50062
# [107]	validation-rmse:6.50142
# [108]	validation-rmse:6.50117
# [109]	validation-rmse:6.50202
# [110]	validation-rmse:6.50278
# [111]	validation-rmse:6.50426
# [112]	validation-rmse:6.50519
# [113]	validation-rmse:6.50876
# [114]	validation-rmse:6.50883
# [115]	validation-rmse:6.50921
# [116]	validation-rmse:6.50988
# [117]	validation-rmse:6.51143
# [118]	validation-rmse:6.51300
# [119]	validation-rmse:6.51569
# [120]	validation-rmse:6.51531
# [121]	validation-rmse:6.51562
# [122]	validation-rmse:6.51653
# [123]	validation-rmse:6.51765
# [124]	validation-rmse:6.51805
# [125]	validation-rmse:6.51877
# [126]	validation-rmse:6.52003
# [127]	validation-rmse:6.51979
# [128]	validation-rmse:6.52046
# [129]	validation-rmse:6.52180
# [130]	validation-rmse:6.52319
# [131]	validation-rmse:6.52423
#   2%|▏         | 1/50 [00:51<42:19, 51.82s/trial, best loss: 6.524226787440519]
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [17:16:37] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:9.50188
# [1]	validation-rmse:8.07468
# [2]	validation-rmse:7.36481
# [3]	validation-rmse:7.01932
# [4]	validation-rmse:6.84335
# [5]	validation-rmse:6.74988
# [6]	validation-rmse:6.69921
# [7]	validation-rmse:6.66681
# [8]	validation-rmse:6.64612
# [9]	validation-rmse:6.62827
# [10]	validation-rmse:6.61831
# [11]	validation-rmse:6.60966
# [12]	validation-rmse:6.60018
# [13]	validation-rmse:6.59448
# [14]	validation-rmse:6.59144
# [15]	validation-rmse:6.58856
# [16]	validation-rmse:6.58735
# [17]	validation-rmse:6.58472
# [18]	validation-rmse:6.58349
# [19]	validation-rmse:6.58163
# [20]	validation-rmse:6.58015
# [21]	validation-rmse:6.57935
# [22]	validation-rmse:6.57884
# [23]	validation-rmse:6.57518
# [24]	validation-rmse:6.57382
# [25]	validation-rmse:6.57200
# [26]	validation-rmse:6.57090
# [27]	validation-rmse:6.57069
# [28]	validation-rmse:6.56999
# [29]	validation-rmse:6.56924
# [30]	validation-rmse:6.56863
# [31]	validation-rmse:6.56727
# [32]	validation-rmse:6.56674
# [33]	validation-rmse:6.56647
# [34]	validation-rmse:6.56512
# [35]	validation-rmse:6.56465
# [36]	validation-rmse:6.56324
# [37]	validation-rmse:6.56259
# [38]	validation-rmse:6.56194
# [39]	validation-rmse:6.56175
# [40]	validation-rmse:6.56088
# [41]	validation-rmse:6.56071
# [42]	validation-rmse:6.56005
# [43]	validation-rmse:6.55989
# [44]	validation-rmse:6.55940
# [45]	validation-rmse:6.55904
# [46]	validation-rmse:6.55861
# [47]	validation-rmse:6.55812
# [48]	validation-rmse:6.55757
# [49]	validation-rmse:6.55736
# [50]	validation-rmse:6.55700
# [51]	validation-rmse:6.55609
# [52]	validation-rmse:6.55577
# [53]	validation-rmse:6.55529
# [54]	validation-rmse:6.55499
# [55]	validation-rmse:6.55484
# [56]	validation-rmse:6.55387
# [57]	validation-rmse:6.55403
# [58]	validation-rmse:6.55353
# [59]	validation-rmse:6.55315
# [60]	validation-rmse:6.55296
# [61]	validation-rmse:6.55238
# [62]	validation-rmse:6.55232
# [63]	validation-rmse:6.55214
# [64]	validation-rmse:6.55174
# [65]	validation-rmse:6.55132
# [66]	validation-rmse:6.55105
# [67]	validation-rmse:6.55105
# [68]	validation-rmse:6.55099
# [69]	validation-rmse:6.55094
# [70]	validation-rmse:6.55048
# [71]	validation-rmse:6.55086
# [72]	validation-rmse:6.55080
# [73]	validation-rmse:6.55042
# [74]	validation-rmse:6.55048
# [75]	validation-rmse:6.55060
# [76]	validation-rmse:6.55034
# [77]	validation-rmse:6.55037
# [78]	validation-rmse:6.55011
# [79]	validation-rmse:6.55010
# [80]	validation-rmse:6.54997
# [81]	validation-rmse:6.54994
# [82]	validation-rmse:6.55004
# [83]	validation-rmse:6.54963
# [84]	validation-rmse:6.54962
# [85]	validation-rmse:6.54962
# [86]	validation-rmse:6.54969
# [87]	validation-rmse:6.54941
# [88]	validation-rmse:6.54915
# [89]	validation-rmse:6.54844
# [90]	validation-rmse:6.54820
# [91]	validation-rmse:6.54808
# [92]	validation-rmse:6.54821
# [93]	validation-rmse:6.54793
# [94]	validation-rmse:6.54770
# [95]	validation-rmse:6.54725
# [96]	validation-rmse:6.54703
# [97]	validation-rmse:6.54701
# [98]	validation-rmse:6.54652
# [99]	validation-rmse:6.54661
# [100]	validation-rmse:6.54605
# [101]	validation-rmse:6.54597
# [102]	validation-rmse:6.54578
# [103]	validation-rmse:6.54600
# [104]	validation-rmse:6.54627
# [105]	validation-rmse:6.54602
# [106]	validation-rmse:6.54599
# [107]	validation-rmse:6.54578
# [108]	validation-rmse:6.54524
# [109]	validation-rmse:6.54562
# [110]	validation-rmse:6.54601
# [111]	validation-rmse:6.54611
# [112]	validation-rmse:6.54607
# [113]	validation-rmse:6.54563
# [114]	validation-rmse:6.54557
# [115]	validation-rmse:6.54547
# [116]	validation-rmse:6.54504
# [117]	validation-rmse:6.54539
# [118]	validation-rmse:6.54482
# [119]	validation-rmse:6.54439
# [120]	validation-rmse:6.54451
# [121]	validation-rmse:6.54436
# [122]	validation-rmse:6.54424
# [123]	validation-rmse:6.54368
# [124]	validation-rmse:6.54336
# [125]	validation-rmse:6.54352
# [126]	validation-rmse:6.54356
# [127]	validation-rmse:6.54345
# [128]	validation-rmse:6.54319
# [129]	validation-rmse:6.54312
# [130]	validation-rmse:6.54304
# [131]	validation-rmse:6.54314
# [132]	validation-rmse:6.54322
# [133]	validation-rmse:6.54310
# [134]	validation-rmse:6.54329
# [135]	validation-rmse:6.54322
# [136]	validation-rmse:6.54305
# [137]	validation-rmse:6.54296
# [138]	validation-rmse:6.54288
# [139]	validation-rmse:6.54275
# [140]	validation-rmse:6.54261
# [141]	validation-rmse:6.54276
# [142]	validation-rmse:6.54249
# [143]	validation-rmse:6.54221
# [144]	validation-rmse:6.54227
# [145]	validation-rmse:6.54215
# [146]	validation-rmse:6.54199
# [147]	validation-rmse:6.54238
# [148]	validation-rmse:6.54215
# [149]	validation-rmse:6.54210
# [150]	validation-rmse:6.54199
# [151]	validation-rmse:6.54185
# [152]	validation-rmse:6.54199
# [153]	validation-rmse:6.54195
# [154]	validation-rmse:6.54199
# [155]	validation-rmse:6.54189
# [156]	validation-rmse:6.54163
# [157]	validation-rmse:6.54148
# [158]	validation-rmse:6.54159
# [159]	validation-rmse:6.54129
# [160]	validation-rmse:6.54104
# [161]	validation-rmse:6.54103
# [162]	validation-rmse:6.54105
# [163]	validation-rmse:6.54106
# [164]	validation-rmse:6.54100
# [165]	validation-rmse:6.54085
# [166]	validation-rmse:6.54121
# [167]	validation-rmse:6.54129
# [168]	validation-rmse:6.54137
# [169]	validation-rmse:6.54074
# [170]	validation-rmse:6.54053
# [171]	validation-rmse:6.54065
# [172]	validation-rmse:6.54064
# [173]	validation-rmse:6.54042
# [174]	validation-rmse:6.54070
# [175]	validation-rmse:6.54050
# [176]	validation-rmse:6.54035
# [177]	validation-rmse:6.54014
# [178]	validation-rmse:6.54025
# [179]	validation-rmse:6.54023
# [180]	validation-rmse:6.54033
# [181]	validation-rmse:6.54034
# [182]	validation-rmse:6.54014
# [183]	validation-rmse:6.54091
# [184]	validation-rmse:6.54116
# [185]	validation-rmse:6.54119
# [186]	validation-rmse:6.54097
# [187]	validation-rmse:6.54075
# [188]	validation-rmse:6.54123
# [189]	validation-rmse:6.54106
# [190]	validation-rmse:6.54097
# [191]	validation-rmse:6.54125
# [192]	validation-rmse:6.54093
# [193]	validation-rmse:6.54081
# [194]	validation-rmse:6.54066
# [195]	validation-rmse:6.54049
# [196]	validation-rmse:6.54055
# [197]	validation-rmse:6.54057
# [198]	validation-rmse:6.54052
# [199]	validation-rmse:6.54019
# [200]	validation-rmse:6.54023
# [201]	validation-rmse:6.54026
# [202]	validation-rmse:6.54047
# [203]	validation-rmse:6.54021
# [204]	validation-rmse:6.54044
# [205]	validation-rmse:6.54028
# [206]	validation-rmse:6.53990
# [207]	validation-rmse:6.53986
# [208]	validation-rmse:6.53979
# [209]	validation-rmse:6.53977
# [210]	validation-rmse:6.53960
# [211]	validation-rmse:6.53963
# [212]	validation-rmse:6.53955
# [213]	validation-rmse:6.53957
# [214]	validation-rmse:6.53956
# [215]	validation-rmse:6.53939
# [216]	validation-rmse:6.53914
# [217]	validation-rmse:6.53913
# [218]	validation-rmse:6.53923
# [219]	validation-rmse:6.53936
# [220]	validation-rmse:6.53912
# [221]	validation-rmse:6.53920
# [222]	validation-rmse:6.53892
# [223]	validation-rmse:6.53928
# [224]	validation-rmse:6.53923
# [225]	validation-rmse:6.53904
# [226]	validation-rmse:6.53892
# [227]	validation-rmse:6.53910
# [228]	validation-rmse:6.53880
# [229]	validation-rmse:6.53876
# [230]	validation-rmse:6.53851
# [231]	validation-rmse:6.53872
# [232]	validation-rmse:6.53863
# [233]	validation-rmse:6.53882
# [234]	validation-rmse:6.53897
# [235]	validation-rmse:6.53893
# [236]	validation-rmse:6.53898
# [237]	validation-rmse:6.53892
# [238]	validation-rmse:6.53909
# [239]	validation-rmse:6.53931
# [240]	validation-rmse:6.53905
# [241]	validation-rmse:6.53905
# [242]	validation-rmse:6.53892
# [243]	validation-rmse:6.53872
# [244]	validation-rmse:6.53887
# [245]	validation-rmse:6.53918
# [246]	validation-rmse:6.53922
# [247]	validation-rmse:6.53911
# [248]	validation-rmse:6.53931
# [249]	validation-rmse:6.53966
# [250]	validation-rmse:6.53965
# [251]	validation-rmse:6.53951
# [252]	validation-rmse:6.53933
# [253]	validation-rmse:6.53935
# [254]	validation-rmse:6.53935
# [255]	validation-rmse:6.53952
# [256]	validation-rmse:6.53941
# [257]	validation-rmse:6.53940
# [258]	validation-rmse:6.53938
# [259]	validation-rmse:6.53955
# [260]	validation-rmse:6.53930
# [261]	validation-rmse:6.53927
# [262]	validation-rmse:6.53930
# [263]	validation-rmse:6.53903
# [264]	validation-rmse:6.53891
# [265]	validation-rmse:6.53889
# [266]	validation-rmse:6.53890
# [267]	validation-rmse:6.53886
# [268]	validation-rmse:6.53900
# [269]	validation-rmse:6.53937
# [270]	validation-rmse:6.53963
# [271]	validation-rmse:6.53938
# [272]	validation-rmse:6.53945
# [273]	validation-rmse:6.53963
# [274]	validation-rmse:6.53927
# [275]	validation-rmse:6.53961
# [276]	validation-rmse:6.53983
# [277]	validation-rmse:6.53965
# [278]	validation-rmse:6.53948
# [279]	validation-rmse:6.53963
# [280]	validation-rmse:6.53963
#   4%|▍         | 2/50 [02:33<1:04:48, 81.00s/trial, best loss: 6.524226787440519]
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [17:18:18] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:9.53916
# [1]	validation-rmse:8.10648
# [2]	validation-rmse:7.37594
# [3]	validation-rmse:7.00828
# [4]	validation-rmse:6.81608
# [5]	validation-rmse:6.71355
# [6]	validation-rmse:6.65585
# [7]	validation-rmse:6.61851
# [8]	validation-rmse:6.59513
# [9]	validation-rmse:6.57944
# [10]	validation-rmse:6.56147
# [11]	validation-rmse:6.54933
# [12]	validation-rmse:6.54255
# [13]	validation-rmse:6.53738
# [14]	validation-rmse:6.53412
# [15]	validation-rmse:6.53050
# [16]	validation-rmse:6.52898
# [17]	validation-rmse:6.52651
# [18]	validation-rmse:6.52469
# [19]	validation-rmse:6.52229
# [20]	validation-rmse:6.52069
# [21]	validation-rmse:6.51870
# [22]	validation-rmse:6.51767
# [23]	validation-rmse:6.51662
# [24]	validation-rmse:6.51549
# [25]	validation-rmse:6.51407
# [26]	validation-rmse:6.51380
# [27]	validation-rmse:6.51328
# [28]	validation-rmse:6.51224
# [29]	validation-rmse:6.51159
# [30]	validation-rmse:6.50974
# [31]	validation-rmse:6.50817
# [32]	validation-rmse:6.50673
# [33]	validation-rmse:6.50627
# [34]	validation-rmse:6.50585
# [35]	validation-rmse:6.50474
# [36]	validation-rmse:6.50358
# [37]	validation-rmse:6.50333
# [38]	validation-rmse:6.50305
# [39]	validation-rmse:6.50259
# [40]	validation-rmse:6.50206
# [41]	validation-rmse:6.50211
# [42]	validation-rmse:6.50143
# [43]	validation-rmse:6.50094
# [44]	validation-rmse:6.50010
# [45]	validation-rmse:6.49984
# [46]	validation-rmse:6.49979
# [47]	validation-rmse:6.49915
# [48]	validation-rmse:6.49853
# [49]	validation-rmse:6.49803
# [50]	validation-rmse:6.49751
# [51]	validation-rmse:6.49696
# [52]	validation-rmse:6.49662
# [53]	validation-rmse:6.49647
# [54]	validation-rmse:6.49647
# [55]	validation-rmse:6.49600
# [56]	validation-rmse:6.49572
# [57]	validation-rmse:6.49565
# [58]	validation-rmse:6.49591
# [59]	validation-rmse:6.49563
# [60]	validation-rmse:6.49521
# [61]	validation-rmse:6.49515
# [62]	validation-rmse:6.49509
# [63]	validation-rmse:6.49431
# [64]	validation-rmse:6.49412
# [65]	validation-rmse:6.49419
# [66]	validation-rmse:6.49329
# [67]	validation-rmse:6.49301
# [68]	validation-rmse:6.49313
# [69]	validation-rmse:6.49287
# [70]	validation-rmse:6.49257
# [71]	validation-rmse:6.49234
# [72]	validation-rmse:6.49180
# [73]	validation-rmse:6.49190
# [74]	validation-rmse:6.49179
# [75]	validation-rmse:6.49154
# [76]	validation-rmse:6.49109
# [77]	validation-rmse:6.49067
# [78]	validation-rmse:6.49072
# [79]	validation-rmse:6.49045
# [80]	validation-rmse:6.49036
# [81]	validation-rmse:6.49065
# [82]	validation-rmse:6.49030
# [83]	validation-rmse:6.49036
# [84]	validation-rmse:6.49003
# [85]	validation-rmse:6.48971
# [86]	validation-rmse:6.48890
# [87]	validation-rmse:6.48921
# [88]	validation-rmse:6.48898
# [89]	validation-rmse:6.48826
# [90]	validation-rmse:6.48831
# [91]	validation-rmse:6.48819
# [92]	validation-rmse:6.48807
# [93]	validation-rmse:6.48801
# [94]	validation-rmse:6.48692
# [95]	validation-rmse:6.48768
# [96]	validation-rmse:6.48706
# [97]	validation-rmse:6.48713
# [98]	validation-rmse:6.48663
# [99]	validation-rmse:6.48705
# [100]	validation-rmse:6.48685
# [101]	validation-rmse:6.48649
# [102]	validation-rmse:6.48695
# [103]	validation-rmse:6.48667
# [104]	validation-rmse:6.48553
# [105]	validation-rmse:6.48571
# [106]	validation-rmse:6.48591
# [107]	validation-rmse:6.48562
# [108]	validation-rmse:6.48564
# [109]	validation-rmse:6.48550
# [110]	validation-rmse:6.48531
# [111]	validation-rmse:6.48508
# [112]	validation-rmse:6.48534
# [113]	validation-rmse:6.48491
# [114]	validation-rmse:6.48461
# [115]	validation-rmse:6.48510
# [116]	validation-rmse:6.48474
# [117]	validation-rmse:6.48444
# [118]	validation-rmse:6.48424
# [119]	validation-rmse:6.48433
# [120]	validation-rmse:6.48443
# [121]	validation-rmse:6.48415
# [122]	validation-rmse:6.48423
# [123]	validation-rmse:6.48418
# [124]	validation-rmse:6.48379
# [125]	validation-rmse:6.48419
# [126]	validation-rmse:6.48379
# [127]	validation-rmse:6.48361
# [128]	validation-rmse:6.48363
# [129]	validation-rmse:6.48353
# [130]	validation-rmse:6.48343
# [131]	validation-rmse:6.48332
# [132]	validation-rmse:6.48332
# [133]	validation-rmse:6.48325
# [134]	validation-rmse:6.48327
# [135]	validation-rmse:6.48341
# [136]	validation-rmse:6.48319
# [137]	validation-rmse:6.48288
# [138]	validation-rmse:6.48244
# [139]	validation-rmse:6.48285
# [140]	validation-rmse:6.48252
# [141]	validation-rmse:6.48245
# [142]	validation-rmse:6.48237
# [143]	validation-rmse:6.48212
# [144]	validation-rmse:6.48195
# [145]	validation-rmse:6.48195
# [146]	validation-rmse:6.48186
# [147]	validation-rmse:6.48166
# [148]	validation-rmse:6.48166
# [149]	validation-rmse:6.48188
# [150]	validation-rmse:6.48170
# [151]	validation-rmse:6.48164
# [152]	validation-rmse:6.48163
# [153]	validation-rmse:6.48155
# [154]	validation-rmse:6.48177
# [155]	validation-rmse:6.48149
# [156]	validation-rmse:6.48140
# [157]	validation-rmse:6.48136
# [158]	validation-rmse:6.48089
# [159]	validation-rmse:6.48103
# [160]	validation-rmse:6.48093
# [161]	validation-rmse:6.48109
# [162]	validation-rmse:6.48150
# [163]	validation-rmse:6.48135
# [164]	validation-rmse:6.48126
# [165]	validation-rmse:6.48104
# [166]	validation-rmse:6.48135
# [167]	validation-rmse:6.48124
# [168]	validation-rmse:6.48115
# [169]	validation-rmse:6.48093
# [170]	validation-rmse:6.48066
# [171]	validation-rmse:6.48057
# [172]	validation-rmse:6.48052
# [173]	validation-rmse:6.48070
# [174]	validation-rmse:6.48058
# [175]	validation-rmse:6.48051
# [176]	validation-rmse:6.48024
# [177]	validation-rmse:6.48022
# [178]	validation-rmse:6.48019
# [179]	validation-rmse:6.48008
# [180]	validation-rmse:6.47995
# [181]	validation-rmse:6.48019
# [182]	validation-rmse:6.48036
# [183]	validation-rmse:6.47968
# [184]	validation-rmse:6.47959
# [185]	validation-rmse:6.47954
# [186]	validation-rmse:6.47970
# [187]	validation-rmse:6.47974
# [188]	validation-rmse:6.47949
# [189]	validation-rmse:6.47928
# [190]	validation-rmse:6.47935
# [191]	validation-rmse:6.47912
# [192]	validation-rmse:6.47910
# [193]	validation-rmse:6.47945
# [194]	validation-rmse:6.47939
# [195]	validation-rmse:6.47884
# [196]	validation-rmse:6.47912
# [197]	validation-rmse:6.47941
# [198]	validation-rmse:6.47936
# [199]	validation-rmse:6.47901
# [200]	validation-rmse:6.47904
# [201]	validation-rmse:6.47878
# [202]	validation-rmse:6.47891
# [203]	validation-rmse:6.47876
# [204]	validation-rmse:6.47872
# [205]	validation-rmse:6.47861
# [206]	validation-rmse:6.47864
# [207]	validation-rmse:6.47876
# [208]	validation-rmse:6.47892
# [209]	validation-rmse:6.47901
# ...
# [28]	validation-rmse:6.45363
# [29]	validation-rmse:6.44877
# [30]	validation-rmse:6.44428
# [31]	validation-rmse:6.44010
# [32]	validation-rmse:6.43641
# [33]	validation-rmse:6.43179
# [34]	validation-rmse:6.42717
# [35]	validation-rmse:6.42501
# [36]	validation-rmse:6.42258
# [37]	validation-rmse:6.42061
# [38]	validation-rmse:6.41834
# [39]	validation-rmse:6.41593
# [40]	validation-rmse:6.41478
# [41]	validation-rmse:6.41293
# [42]	validation-rmse:6.41139
# [43]	validation-rmse:6.41080
# [44]	validation-rmse:6.40986
# [45]	validation-rmse:6.40841
# [46]	validation-rmse:6.40717
# [47]	validation-rmse:6.40606
# [48]	validation-rmse:6.40450
# [49]	validation-rmse:6.40260
# [50]	validation-rmse:6.40208
# [51]	validation-rmse:6.40111
# [52]	validation-rmse:6.40021
# [53]	validation-rmse:6.39837
# [54]	validation-rmse:6.39745
# [55]	validation-rmse:6.39651
# [56]	validation-rmse:6.39573
# [57]	validation-rmse:6.39460
# [58]	validation-rmse:6.39402
# [59]	validation-rmse:6.39298
# [60]	validation-rmse:6.39219
# [61]	validation-rmse:6.39173
# [62]	validation-rmse:6.39043
# [63]	validation-rmse:6.38960
# [64]	validation-rmse:6.38904
# [65]	validation-rmse:6.38827
# [66]	validation-rmse:6.38767
# [67]	validation-rmse:6.38725
# [68]	validation-rmse:6.38650
# [69]	validation-rmse:6.38629
# [70]	validation-rmse:6.38545
# [71]	validation-rmse:6.38473
# [72]	validation-rmse:6.38406
# [73]	validation-rmse:6.38342
# [74]	validation-rmse:6.38257
# [75]	validation-rmse:6.38214
# [76]	validation-rmse:6.38169
# [77]	validation-rmse:6.38152
# [78]	validation-rmse:6.38021
# [79]	validation-rmse:6.37971
# [80]	validation-rmse:6.37893
# [81]	validation-rmse:6.37842
# [82]	validation-rmse:6.37773
# [83]	validation-rmse:6.37716
# [84]	validation-rmse:6.37678
# [85]	validation-rmse:6.37583
# [86]	validation-rmse:6.37542
# [87]	validation-rmse:6.37514
# [88]	validation-rmse:6.37467
# [89]	validation-rmse:6.37423
# [90]	validation-rmse:6.37426
# [91]	validation-rmse:6.37366
# [92]	validation-rmse:6.37303
# [93]	validation-rmse:6.37272
# [94]	validation-rmse:6.37215
# [95]	validation-rmse:6.37197
# [96]	validation-rmse:6.37130
# [97]	validation-rmse:6.37101
# [98]	validation-rmse:6.37042
# [99]	validation-rmse:6.37005
# [100]	validation-rmse:6.36976
# [101]	validation-rmse:6.36899
# [102]	validation-rmse:6.36854
# [103]	validation-rmse:6.36822
# [104]	validation-rmse:6.36769
# [105]	validation-rmse:6.36723
# [106]	validation-rmse:6.36672
# [107]	validation-rmse:6.36667
# [108]	validation-rmse:6.36598
# [109]	validation-rmse:6.36602
# [110]	validation-rmse:6.36555
# [111]	validation-rmse:6.36514
# [112]	validation-rmse:6.36446
# [113]	validation-rmse:6.36423
# [114]	validation-rmse:6.36394
# [115]	validation-rmse:6.36357
# [116]	validation-rmse:6.36322
# [117]	validation-rmse:6.36275
# [118]	validation-rmse:6.36244
# [119]	validation-rmse:6.36237
# [120]	validation-rmse:6.36210
# [121]	validation-rmse:6.36170
# [122]	validation-rmse:6.36138
# [123]	validation-rmse:6.36112
# [124]	validation-rmse:6.36097
# [125]	validation-rmse:6.36069
# [126]	validation-rmse:6.36015
# [127]	validation-rmse:6.36014
# [128]	validation-rmse:6.36001
# [129]	validation-rmse:6.35949
# [130]	validation-rmse:6.35927
# [131]	validation-rmse:6.35879
# [132]	validation-rmse:6.35825
# [133]	validation-rmse:6.35822
# [134]	validation-rmse:6.35787
# [135]	validation-rmse:6.35769
# [136]	validation-rmse:6.35751
#  14%|█▍        | 7/50 [16:02<1:38:33, 137.53s/trial, best loss: 6.378871885696459]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 11
#       1 search_space = {
#       2     'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
#       3     'learning_rate': hp.loguniform('learning_rate', -3, 0),
#    (...)
#       8     'seed': 42
#       9 }
# ---> 11 best_result = fmin(
#      12     fn=objective,
#      13     space=search_space,
#      14     algo=tpe.suggest,
#      15     max_evals=50,
#      16     trials=Trials()
#      17 )
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[20], line 5, in objective(params)
#       3 mlflow.set_tag("model", "xgboost")
#       4 mlflow.log_params(params)
# ----> 5 booster = xgb.train(
#       6     params=params,
#       7     dtrain=train,
#       8     num_boost_round=1000,
#       9     evals=[(valid, 'validation')],
#      10     early_stopping_rounds=50
#      11 )
#      12 y_pred = booster.predict(valid)
#      13 rmse = root_mean_squared_error(y_val, y_pred)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, iteration=i, fobj=obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:2101, in Booster.update(self, dtrain, iteration, fobj)
#    2097 self._assign_dmatrix_features(dtrain)
#    2099 if fobj is None:
#    2100     _check_call(
# -> 2101         _LIB.XGBoosterUpdateOneIter(
#    2102             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2103         )
#    2104     )
#    2105 else:
#    2106     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
mlflow.xgboost.autolog(disable=True)

# %%
with mlflow.start_run():
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.09585355369315604,
        'max_depth': 30,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:linear',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = root_mean_squared_error(y_val, y_pred)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# /home/codespace/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [17:32:59] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:11.44482
# [1]	validation-rmse:10.77202
# [2]	validation-rmse:10.18363
# [3]	validation-rmse:9.67396
# [4]	validation-rmse:9.23166
# [5]	validation-rmse:8.84808
# [6]	validation-rmse:8.51883
# [7]	validation-rmse:8.23597
# [8]	validation-rmse:7.99320
# [9]	validation-rmse:7.78709
# [10]	validation-rmse:7.61022
# [11]	validation-rmse:7.45952
# [12]	validation-rmse:7.33049
# [13]	validation-rmse:7.22098
# [14]	validation-rmse:7.12713
# [15]	validation-rmse:7.04752
# [16]	validation-rmse:6.98005
# [17]	validation-rmse:6.92232
# [18]	validation-rmse:6.87112
# [19]	validation-rmse:6.82740
# [20]	validation-rmse:6.78995
# [21]	validation-rmse:6.75792
# [22]	validation-rmse:6.72994
# [23]	validation-rmse:6.70547
# [24]	validation-rmse:6.68390
# [25]	validation-rmse:6.66421
# [26]	validation-rmse:6.64806
# [27]	validation-rmse:6.63280
# [28]	validation-rmse:6.61924
# [29]	validation-rmse:6.60773
# [30]	validation-rmse:6.59777
# [31]	validation-rmse:6.58875
# [32]	validation-rmse:6.58107
# [33]	validation-rmse:6.57217
# [34]	validation-rmse:6.56557
# [35]	validation-rmse:6.56003
# [36]	validation-rmse:6.55392
# [37]	validation-rmse:6.54924
# [38]	validation-rmse:6.54536
# [39]	validation-rmse:6.54187
# [40]	validation-rmse:6.53873
# [41]	validation-rmse:6.53518
# [42]	validation-rmse:6.53287
# [43]	validation-rmse:6.53048
# [44]	validation-rmse:6.52858
# [45]	validation-rmse:6.52703
# [46]	validation-rmse:6.52566
# [47]	validation-rmse:6.52419
# [48]	validation-rmse:6.52323
# [49]	validation-rmse:6.52265
# [50]	validation-rmse:6.52202
# [51]	validation-rmse:6.52036
# [52]	validation-rmse:6.52003
# [53]	validation-rmse:6.51962
# [54]	validation-rmse:6.51829
# [55]	validation-rmse:6.51712
# [56]	validation-rmse:6.51598
# [57]	validation-rmse:6.51517
# [58]	validation-rmse:6.51442
# [59]	validation-rmse:6.51357
# [60]	validation-rmse:6.51194
# [61]	validation-rmse:6.51127
# [62]	validation-rmse:6.51044
# [63]	validation-rmse:6.50930
# [64]	validation-rmse:6.50840
# [65]	validation-rmse:6.50731
# [66]	validation-rmse:6.50635
# [67]	validation-rmse:6.50566
# [68]	validation-rmse:6.50458
# [69]	validation-rmse:6.50339
# [70]	validation-rmse:6.50239
# [71]	validation-rmse:6.50137
# [72]	validation-rmse:6.50014
# [73]	validation-rmse:6.49940
# [74]	validation-rmse:6.49835
# [75]	validation-rmse:6.49782
# [76]	validation-rmse:6.49697
# [77]	validation-rmse:6.49628
# [78]	validation-rmse:6.49561
# [79]	validation-rmse:6.49495
# [80]	validation-rmse:6.49429
# [81]	validation-rmse:6.49371
# [82]	validation-rmse:6.49317
# [83]	validation-rmse:6.49248
# [84]	validation-rmse:6.49170
# [85]	validation-rmse:6.49080
# [86]	validation-rmse:6.49020
# [87]	validation-rmse:6.48927
# [88]	validation-rmse:6.48842
# [89]	validation-rmse:6.48717
# [90]	validation-rmse:6.48666
# [91]	validation-rmse:6.48608
# [92]	validation-rmse:6.48531
# [93]	validation-rmse:6.48457
# [94]	validation-rmse:6.48376
# [95]	validation-rmse:6.48304
# [96]	validation-rmse:6.48246
# [97]	validation-rmse:6.48113
# [98]	validation-rmse:6.48052
# [99]	validation-rmse:6.47984
# [100]	validation-rmse:6.47922
# [101]	validation-rmse:6.47886
# [102]	validation-rmse:6.47819
# [103]	validation-rmse:6.47742
# [104]	validation-rmse:6.47685
# [105]	validation-rmse:6.47643
# [106]	validation-rmse:6.47616
# [107]	validation-rmse:6.47583
# [108]	validation-rmse:6.47530
# [109]	validation-rmse:6.47479
# [110]	validation-rmse:6.47409
# [111]	validation-rmse:6.47339
# [112]	validation-rmse:6.47296
# [113]	validation-rmse:6.47250
# [114]	validation-rmse:6.47148
# [115]	validation-rmse:6.47089
# [116]	validation-rmse:6.47037
# [117]	validation-rmse:6.46947
# [118]	validation-rmse:6.46907
# [119]	validation-rmse:6.46840
# [120]	validation-rmse:6.46749
# [121]	validation-rmse:6.46701
# [122]	validation-rmse:6.46612
# [123]	validation-rmse:6.46538
# [124]	validation-rmse:6.46467
# [125]	validation-rmse:6.46413
# [126]	validation-rmse:6.46350
# [127]	validation-rmse:6.46265
# [128]	validation-rmse:6.46225
# [129]	validation-rmse:6.46169
# [130]	validation-rmse:6.46065
# [131]	validation-rmse:6.46022
# [132]	validation-rmse:6.45980
# [133]	validation-rmse:6.45918
# [134]	validation-rmse:6.45844
# [135]	validation-rmse:6.45802
# [136]	validation-rmse:6.45783
# [137]	validation-rmse:6.45746
# [138]	validation-rmse:6.45661
# [139]	validation-rmse:6.45619
# [140]	validation-rmse:6.45566
# [141]	validation-rmse:6.45554
# [142]	validation-rmse:6.45487
# [143]	validation-rmse:6.45461
# [144]	validation-rmse:6.45411
# [145]	validation-rmse:6.45325
# [146]	validation-rmse:6.45278
# [147]	validation-rmse:6.45215
# [148]	validation-rmse:6.45174
# [149]	validation-rmse:6.45146
# [150]	validation-rmse:6.45113
# [151]	validation-rmse:6.45076
# [152]	validation-rmse:6.45012
# [153]	validation-rmse:6.44965
# [154]	validation-rmse:6.44905
# [155]	validation-rmse:6.44872
# [156]	validation-rmse:6.44825
# [157]	validation-rmse:6.44792
# [158]	validation-rmse:6.44743
# [159]	validation-rmse:6.44671
# [160]	validation-rmse:6.44616
# [161]	validation-rmse:6.44562
# [162]	validation-rmse:6.44503
# [163]	validation-rmse:6.44434
# [164]	validation-rmse:6.44399
# [165]	validation-rmse:6.44339
# [166]	validation-rmse:6.44303
# [167]	validation-rmse:6.44260
# [168]	validation-rmse:6.44207
# [169]	validation-rmse:6.44173
# [170]	validation-rmse:6.44107
# [171]	validation-rmse:6.44068
# [172]	validation-rmse:6.44007
# [173]	validation-rmse:6.43964
# [174]	validation-rmse:6.43918
# [175]	validation-rmse:6.43883
# [176]	validation-rmse:6.43842
# [177]	validation-rmse:6.43803
# [178]	validation-rmse:6.43759
# [179]	validation-rmse:6.43714
# [180]	validation-rmse:6.43676
# [181]	validation-rmse:6.43644
# [182]	validation-rmse:6.43605
# [183]	validation-rmse:6.43571
# [184]	validation-rmse:6.43527
# [185]	validation-rmse:6.43489
# [186]	validation-rmse:6.43435
# [187]	validation-rmse:6.43408
# [188]	validation-rmse:6.43376
# [189]	validation-rmse:6.43360
# [190]	validation-rmse:6.43347
# [191]	validation-rmse:6.43343
# [192]	validation-rmse:6.43284
# [193]	validation-rmse:6.43259
# [194]	validation-rmse:6.43222
# [195]	validation-rmse:6.43187
# [196]	validation-rmse:6.43157
# [197]	validation-rmse:6.43102
# [198]	validation-rmse:6.43084
# [199]	validation-rmse:6.43085
# [200]	validation-rmse:6.43072
# [201]	validation-rmse:6.43048
# [202]	validation-rmse:6.43004
# [203]	validation-rmse:6.42961
# [204]	validation-rmse:6.42896
# [205]	validation-rmse:6.42861
# [206]	validation-rmse:6.42831
# [207]	validation-rmse:6.42808
# [208]	validation-rmse:6.42801
# [209]	validation-rmse:6.42755
# [210]	validation-rmse:6.42700
# [211]	validation-rmse:6.42653
# [212]	validation-rmse:6.42617
# [213]	validation-rmse:6.42564
# [214]	validation-rmse:6.42532
# [215]	validation-rmse:6.42478
# [216]	validation-rmse:6.42448
# [217]	validation-rmse:6.42402
# [218]	validation-rmse:6.42359
# [219]	validation-rmse:6.42338
# [220]	validation-rmse:6.42298
# [221]	validation-rmse:6.42271
# [222]	validation-rmse:6.42247
# [223]	validation-rmse:6.42197
# [224]	validation-rmse:6.42171
# [225]	validation-rmse:6.42122
# [226]	validation-rmse:6.42061
# [227]	validation-rmse:6.42051
# [228]	validation-rmse:6.42004
# [229]	validation-rmse:6.41970
# [230]	validation-rmse:6.41931
# [231]	validation-rmse:6.41891
# [232]	validation-rmse:6.41880
# [233]	validation-rmse:6.41871
# [234]	validation-rmse:6.41846
# [235]	validation-rmse:6.41782
# [236]	validation-rmse:6.41750
# [237]	validation-rmse:6.41718
# [238]	validation-rmse:6.41680
# [239]	validation-rmse:6.41642
# [240]	validation-rmse:6.41611
# [241]	validation-rmse:6.41599
# [242]	validation-rmse:6.41567
# [243]	validation-rmse:6.41528
# [244]	validation-rmse:6.41504
# [245]	validation-rmse:6.41465
# [246]	validation-rmse:6.41431
# [247]	validation-rmse:6.41400
# [248]	validation-rmse:6.41364
# [249]	validation-rmse:6.41342
# [250]	validation-rmse:6.41328
# [251]	validation-rmse:6.41325
# [252]	validation-rmse:6.41308
# [253]	validation-rmse:6.41279
# [254]	validation-rmse:6.41259
# [255]	validation-rmse:6.41198
# [256]	validation-rmse:6.41179
# [257]	validation-rmse:6.41155
# [258]	validation-rmse:6.41131
# [259]	validation-rmse:6.41075
# [260]	validation-rmse:6.41055
# [261]	validation-rmse:6.41016
# [262]	validation-rmse:6.41002
# [263]	validation-rmse:6.41006
# [264]	validation-rmse:6.40985
# [265]	validation-rmse:6.40970
# [266]	validation-rmse:6.40951
# [267]	validation-rmse:6.40926
# [268]	validation-rmse:6.40903
# [269]	validation-rmse:6.40865
# [270]	validation-rmse:6.40830
# [271]	validation-rmse:6.40805
# [272]	validation-rmse:6.40790
# [273]	validation-rmse:6.40767
# [274]	validation-rmse:6.40749
# [275]	validation-rmse:6.40734
# [276]	validation-rmse:6.40696
# [277]	validation-rmse:6.40666
# [278]	validation-rmse:6.40632
# [279]	validation-rmse:6.40581
# [280]	validation-rmse:6.40552
# [281]	validation-rmse:6.40505
# [282]	validation-rmse:6.40472
# [283]	validation-rmse:6.40449
# [284]	validation-rmse:6.40420
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 18
#       6 best_params = {
#       7     'learning_rate': 0.09585355369315604,
#       8     'max_depth': 30,
#    (...)
#      13     'seed': 42
#      14 }
#      16 mlflow.log_params(best_params)
# ---> 18 booster = xgb.train(
#      19     params=best_params,
#      20     dtrain=train,
#      21     num_boost_round=1000,
#      22     evals=[(valid, 'validation')],
#      23     early_stopping_rounds=50
#      24 )
#      26 y_pred = booster.predict(valid)
#      27 rmse = root_mean_squared_error(y_val, y_pred)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, iteration=i, fobj=obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:2101, in Booster.update(self, dtrain, iteration, fobj)
#    2097 self._assign_dmatrix_features(dtrain)
#    2099 if fobj is None:
#    2100     _check_call(
# -> 2101         _LIB.XGBoosterUpdateOneIter(
#    2102             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2103         )
#    2104     )
#    2105 else:
#    2106     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):

    with mlflow.start_run():

        mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
        mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
# Out:
# /Users/cristian.martinez/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
